# %% [markdown]
# # **Netflix Analysis**

# %% [markdown]
# ## EDA - Análise Exploratória de Dados
#
# ### Fonte dos Dados
#
# Os dados utilizados neste projeto são derivados do dataset público **"Netflix Movies and TV Shows"**, originalmente disponibilizado no Kaggle.
#
# **Autor: Ana Carolina Itacarambi**

# %%
# Importando bibliotecas
import pandas as pd
